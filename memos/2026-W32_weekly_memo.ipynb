# %% [markdown]
# # Weekly Macro Memo — Week of 07 August 2026 (ISO week 32, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 07 August 2026

# %% [markdown]
# ## This week's macro backdrop
#
# US yields eased back this week — 10Y down from 4.75% to 4.65% — but 2s10s held up well, at +0.46pp versus +0.47pp last week, because the front end (2Y) eased by almost exactly as much as the back end. That's constructive for the steepener: a curve that holds its shape through a modest rally, rather than immediately flattening the moment yields stop rising, is a better sign of a durable steepening regime than last week's single sharp widening was on its own.
#
# USDJPY continued strengthening — 158.34, down again from 160.24 — confirming that last week's reversal was not a one-off. Good news for having closed the short-JPY leg promptly rather than holding on hoping for a bounce that hasn't come.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-08-07 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** hold the 2s10s steepener; no JPY position (correctly stayed out after last week's stop)
# - **Direction & size (illustrative):** unchanged
# - **Entry context:** curve holding shape through a modest rally — two consecutive weeks of a stable-to-widening spread is a firmer base than one
# - **Time horizon:** unchanged, 6-8 week window from last week
# - **Catalyst(s) to watch:** US payrolls and CPI over the coming weeks, which will be the real test of whether the curve keeps this shape into the autumn

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** a flattening back toward June's +0.35pp range
# - **Key risks to the trade:** none new; the discipline this week is simply not over-trading a position that's working, and not chasing JPY back in on a hunch that the yen move has further to run without a fresh catalyst
# - **Invalidation level / stop condition:** unchanged from last week (+0.35pp)

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
