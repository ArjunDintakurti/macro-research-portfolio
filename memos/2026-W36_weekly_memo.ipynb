# %% [markdown]
# # Positioning for a decision that hasn't happened yet
#
# *Weekly note — week ending 04 September 2026*

# %% [markdown]
# Last week's front-end repricing didn't reverse — if anything it continued, with the 2-year yield ticking up again and the 10-year following closely enough that 2s10s only recovered marginally. The clearer story this week sits further out on the curve and in FX: 5s30s compressed for a second straight week, and USD/JPY fell sharply, from just under 160 to just above 156 — the largest yen move since the reversal back in late July.
#
# A simultaneous flattening at the long end and a sharp yen rally, roughly two weeks before a Federal Reserve decision, has a fairly recognisable shape to it: markets trimming risk and unwinding carry positions ahead of a known event, rather than expressing a fresh directional conviction. That's a different kind of move from the ones earlier in this series that were driven by an actual data surprise — this is positioning *ahead of* an outcome, which tends to be faster and less tied to any single new piece of information than a post-data move would be.
#
# The Fed's meeting on 15-16 September is now the obvious focal point for everything in this note. When the front end of the curve is already repricing meaningfully three weeks out, it's a reasonable sign that the meeting itself is likely to matter a great deal for how the rest of this series plays out — which is exactly the kind of set-up worth flagging clearly rather than waiting to discuss only after the fact.

# %%
# chart

# %% [markdown]
# *Source: ECB reference rates, via the Frankfurter API*
