# %% [markdown]
# # Two stories, moving in opposite directions
#
# *Weekly note — week ending 31 July 2026*

# %% [markdown]
# This week answered the question posed last Friday, and answered it emphatically. USD/JPY didn't grind further — it reversed hard, falling from above 163 to just above 160 in five trading days, the sharpest single-week FX move anywhere in this series so far. A month of gradual yen weakness unwound in a week, which is exactly the pattern carry trades tend to follow: slow to build, fast to come off, usually without a single clean headline explaining why on the day itself.
#
# At the same time, and unrelated in any obvious way, the US curve did something it hadn't done yet this summer: it actually steepened, rather than shifting in parallel. 2s10s widened from roughly 0.36 percentage points to 0.47 — the sharpest weekly widening in the series to date — while the 10-year and 30-year both pushed to new highs for the period, above 4.75% and 5.25% respectively. A steepening curve alongside rising long-end yields is consistent with the market leaning further into a "no recession, gradual normalisation" read of the cycle, rather than the parallel repricing seen the week before.
#
# It's worth being honest about the two stories not obviously being connected — this note isn't going to force a single narrative onto them just because they happened in the same week. What they share is a lesson about timing: both moves arrived abruptly after a build-up (the yen after four weeks of drift, the curve after three weeks of doing very little), which is a useful reminder that gradual trends in this market have a habit of resolving suddenly rather than petering out quietly.

# %%
# chart

# %% [markdown]
# *Source: ECB reference rates, via the Frankfurter API*
