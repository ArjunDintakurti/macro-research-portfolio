# %% [markdown]
# # Weekly Macro Memo — Week of 03 July 2026 (ISO week 27, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 03 July 2026

# %% [markdown]
# ## This week's macro backdrop
#
# First entry in this series, so a word on method before the view: every chart below comes from the same public data feeds behind the four dashboard notebooks in this portfolio — nothing here is a Bloomberg terminal screenshot or a desk-only dataset, which is a real constraint worth stating up front rather than glossing over.
#
# The US curve is unremarkable this week: 2s10s sits at +0.35pp, 5s30s at +0.75pp, both comfortably positive. That itself is the story. A curve that spent much of 2022-23 flirting with inversion is now solidly upward-sloping, which is the market's way of saying a recession is not the base case and that the Fed's easing cycle (Fed funds effective at 3.63%, down from the 5.33% peak) is being read as normalisation rather than panic. US CPI YoY at 3.54% is still above target, so this is a gradual, not a victory-lap, disinflation.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-07-03 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** modest 2s10s steepener (long 10Y / short 2Y US Treasury exposure, expressed via futures or an ETF pair rather than cash bonds given account size)
# - **Direction & size (illustrative):** small — this is a continuation-of-trend view, not a high-conviction call
# - **Entry context:** curve already positively sloped (+0.35pp); the trade is a bet that normalisation continues rather than reverses, not a bet on a new regime
# - **Time horizon:** 4-6 weeks
# - **Catalyst(s) to watch:** the next US CPI print, and any Fedspeak on the pace of further cuts

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** a re-inversion of 2s10s, which would suggest the market has started pricing recession risk back in
# - **Key risks to the trade:** this is a low-conviction, small-size position specifically because a single week of data is a thin base for a directional call — the main risk is over-interpreting noise as trend
# - **Invalidation level / stop condition:** 2s10s printing flat or negative on a sustained (multi-day) basis

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
