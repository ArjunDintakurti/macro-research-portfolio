# %% [markdown]
# # Weekly Macro Memo — Week of 14 August 2026 (ISO week 33, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 14 August 2026

# %% [markdown]
# ## This week's macro backdrop
#
# 2s10s widened again, to +0.51pp — the widest print in the series to date, and the third consecutive week the spread has either widened or held. That's now a genuine four-week pattern rather than a single data point, which is a meaningfully stronger evidence base than the position had when it was opened back in week one on a single week of +0.35pp.
#
# Away from rates, GBPUSD and EURUSD both continued a slow grind higher (1.1567 and 1.3537 respectively, both up modestly on the week) with nothing dramatic behind either move — more consistent with broad, gradual dollar softness than a UK- or euro-area-specific story, which fits with US yields having eased slightly from their late-July peak even as the curve itself stayed steep.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-08-14 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** hold the 2s10s steepener; still no active JPY position
# - **Direction & size (illustrative):** unchanged; not adding further even though the trend has strengthened, since the position is already at the size ceiling set for a "small-plus, tactical, undergraduate portfolio" position from the outset
# - **Entry context:** four consecutive weeks of a widening-or-stable spread
# - **Time horizon:** holding through August, will reassess around the next FOMC-adjacent data
# - **Catalyst(s) to watch:** any signs the broad-dollar softness behind the GBP/EUR grind is starting to show up in the US curve itself

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** as before, a flattening back toward +0.35pp or below
# - **Key risks to the trade:** four good weeks in a row is exactly the point at which it's tempting to increase size on a position that's "clearly working" — resisting that, given the sample is still short, is itself the discipline being practised here
# - **Invalidation level / stop condition:** unchanged

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
