# %% [markdown]
# # Four weeks in the same direction
#
# *Weekly note — week ending 14 August 2026*

# %% [markdown]
# 2s10s widened again this week, to a touch above 0.5 percentage points — the widest print anywhere in this series so far, and now the third consecutive week the spread has either widened or held its ground rather than reversed. That's a meaningfully firmer evidence base for a steepening view than the single sharp move back in late July offered on its own; a trend that survives four weeks, including a week where yields fell, is harder to dismiss as noise.
#
# Away from rates, sterling and the euro both continued a slow grind higher against the dollar this week, with nothing dramatic behind either move individually — more consistent with a broadly softer dollar than with anything UK- or euro-specific happening. That fits reasonably well with US yields having eased slightly from their late-July peak even while the curve itself stayed steep: a market that's less urgently bidding for dollar assets at the margin, without any change in its underlying view on the shape of the US cycle.
#
# There's a temptation, four good weeks into a trend, to treat it as settled and stop questioning it — which is worth resisting deliberately rather than by accident. Nothing this week suggests the steepening is about to reverse, but the whole value of a series like this one is checking the thesis fresh each week rather than assuming last week's conclusion still holds.

# %%
# chart

# %% [markdown]
# *Source: US Treasury daily par yield curve*
