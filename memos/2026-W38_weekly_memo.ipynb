# %% [markdown]
# # Weekly Macro Memo — Week of 18 September 2026 (ISO week 38, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 18 September 2026

# %% [markdown]
# ## This week's macro backdrop
#
# The FOMC met on 15-16 September, and this week's data shows the outcome was, if anything, more hawkish than the market had already priced going in. The 2Y yield rose further still, to 4.76%, and the 10Y crossed 5.00% for the first time in this series (5.01%) — a genuinely significant round-number breach. 2s10s compressed to +0.25pp and 5s30s to +0.48pp, both the flattest prints of the entire twelve weeks, confirming the flattening thesis in full at the event it was explicitly positioned for.
#
# USDJPY partially reversed post-meeting, to 157.89 from the 154.04 low the week before — a real bounce (roughly 2.5%), consistent with some of the pre-FOMC carry-unwind positioning being closed out now that the event risk has passed, rather than the yen continuing to strengthen on fresh news.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-09-18 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** take profit on the majority of the 5s30s flattener; the thesis has now played out at the specific event it was built around, which is the natural point to reduce rather than let a working position run indefinitely on inertia
# - **Direction & size (illustrative):** reduced from small-plus back to small, holding a residual position rather than closing entirely, in case the post-FOMC flattening trend has further to run into October
# - **Entry context:** 5s30s at the flattest print of the series, immediately post-FOMC
# - **Time horizon:** residual position held through early October, reassessed against the next data prints rather than another scheduled event
# - **Catalyst(s) to watch:** US data over the next few weeks (the next CPI print in particular) to see whether the market's hawkish repricing this month holds up against actual inflation data, or whether it was more about the dot plot than the incoming numbers

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** a swift re-steepening over the following two weeks would suggest the post-FOMC move was itself an overshoot
# - **Key risks to the trade:** the JPY bounce this week is a reminder that "the event happened, the thesis was right" is not the same as "there's nothing left to learn" — the size reduction reflects that the highest-conviction part of this trade (the FOMC itself) has now passed
# - **Invalidation level / stop condition:** 5s30s back above +0.60pp would close the residual position entirely
#
# ---
#
# **Twelve-week retrospective (end of this run):** the series moved from a steepener thesis (weeks 27-33, on a curve normalising away from inversion) through a deliberate flat period after being wrong-footed once on JPY timing (weeks 34-35), into a flattener thesis (weeks 36-38) that was validated sharply around a real, correctly-anticipated FOMC event. The single clearest lesson across twelve weeks: the sharpest, most tradeable moves (JPY in week 5, the curve in weeks 37-38) both arrived faster than the gradual trends that preceded them — which is exactly the kind of pattern a purely trend-following approach would miss, and worth carrying into whatever the next twelve weeks of this portfolio look at.

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
