# %% [markdown]
# # The Fed met, and the market's bet paid off
#
# *Weekly note — week ending 18 September 2026*

# %% [markdown]
# The Federal Reserve's Federal Open Market Committee met on 15-16 September, and the data this week suggests the outcome was, if anything, slightly more hawkish than what the market had already priced going in. The 2-year yield climbed further still, and the 10-year crossed 5% for the first time in this series — a genuinely significant round-number breach for a market that had spent most of the summer comfortably below it. 2s10s and 5s30s both compressed to the flattest prints recorded anywhere in these twelve weeks, closing out the series at its most decisively flattened point.
#
# That's the neat, satisfying version of this week's story, and it's worth being honest about the messier part too: USD/JPY, which had fallen for four straight weeks into the meeting, actually bounced afterward — a real reversal of roughly two and a half percent, consistent with some of that pre-meeting carry-unwind positioning being closed out now that the event risk has passed, rather than the yen continuing to strengthen on fresh news.
#
# Looking back across the full twelve weeks: this series moved from a curve that had simply stopped inverting, through a steepening phase built on a gradual, multi-week trend, into a sharp reversal once the market started positioning explicitly for a known event — and the sharpest, most tradeable moves throughout (the yen's reversal in late July, the curve's compression into September) both arrived faster than the gradual trends that preceded them. That's arguably the one lesson worth carrying forward past this series: the quiet weeks build the position, but it's rarely the quiet weeks that resolve it.

# %%
# chart

# %% [markdown]
# *Source: US Treasury daily par yield curve*
