# %% [markdown]
# # The sharpest week in this entire series
#
# *Weekly note — week ending 11 September 2026*

# %% [markdown]
# This is, by a wide margin, the biggest move recorded anywhere in this run of notes. The 2-year Treasury yield surged by roughly 26 basis points in a single week — more than double any previous weekly change — with the 10-year following it up to just short of 5%. 2s10s compressed to around 0.33 percentage points and 5s30s fell hard too, confirming in one decisive week what had been building gradually since the reversal two weeks ago.
#
# USD/JPY extended its decline to its lowest point in this entire series, a fourth consecutive week of yen strength and the clearest evidence yet of carry positions being unwound ahead of the Fed's decision, now just days away. What stands out is that markets aren't waiting for the meeting itself to reposition — they're doing it in advance, and doing it forcefully, which says something about how confident the market has become in a hawkish outcome before the Fed has actually delivered one.
#
# There's a genuine tension worth naming plainly here rather than glossing over: a market this convinced, this early, of a particular outcome is also a market with more room to be surprised if the actual decision comes in even slightly different from what's already priced. That's simply how positioning ahead of a binary event works — the more confidently the market leans one way beforehand, the sharper the potential reaction if the event doesn't confirm it.

# %%
# chart

# %% [markdown]
# *Source: ECB reference rates, via the Frankfurter API*
