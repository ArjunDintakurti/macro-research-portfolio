# %% [markdown]
# # Weekly Macro Memo — Week of 11 September 2026 (ISO week 37, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 11 September 2026

# %% [markdown]
# ## This week's macro backdrop
#
# This is the sharpest move of the entire series. The 2Y yield surged from 4.37% to 4.63% — a 26bp move in a week, more than double any prior weekly change — with the 10Y following to 4.96%, just short of the 5% mark. 2s10s compressed to +0.33pp and 5s30s compressed hard, from +0.70pp to +0.57pp, confirming the flattening thesis opened last week in a single, decisive week rather than the gradual grind seen in the steepener earlier in the series.
#
# USDJPY extended its decline to 154.04, the lowest print in the series — a fourth consecutive week of yen strength and the clearest sign yet of carry-trade unwinding ahead of the FOMC decision now just days away (16 September). Markets are not waiting for the meeting to reposition; they are doing it in advance, which is itself informative about how confident the market is in a hawkish outcome.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-09-11 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** hold and add modestly to the 5s30s flattener, now working sharply; continue to avoid a standalone JPY position given the position is already expressed indirectly through the flattener's front-end exposure
# - **Direction & size (illustrative):** flattener increased from small to small-plus given the scale of confirmation this week; still deliberately capped ahead of the FOMC itself given event risk
# - **Entry context:** 5s30s at +0.57pp, sharpest weekly compression of the series
# - **Time horizon:** through the FOMC decision (16 September) and the following week, then reassess regardless of outcome
# - **Catalyst(s) to watch:** the FOMC decision itself, now the single dominant catalyst for every series in this memo

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** if the FOMC delivers a dovish surprise relative to what this week's pricing implies, the unwind could be as sharp as this week's move was in the other direction
# - **Key risks to the trade:** adding to a position two working days before a binary event is a genuine risk-management question, not just a technical one — sized small-plus rather than large specifically because of that
# - **Invalidation level / stop condition:** 5s30s back above +0.65pp on a closing basis post-FOMC would be treated as the thesis failing at the event itself

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
