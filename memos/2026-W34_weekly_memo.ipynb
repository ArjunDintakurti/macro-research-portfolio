# %% [markdown]
# # Weekly Macro Memo — Week of 21 August 2026 (ISO week 34, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 21 August 2026

# %% [markdown]
# ## This week's macro backdrop
#
# GBPUSD hit 1.1699 this week, its high for the whole series, with EURUSD close behind at 1.3656 — both currencies extending the broad-dollar-softness pattern flagged last week into a fifth consecutive week. The US curve, meanwhile, held roughly steady: 2s10s at +0.50pp, essentially unchanged from +0.51pp, with both the 2Y and 10Y ticking up together by a similar amount (2Y 4.17%→4.24%, 10Y 4.68%→4.74%).
#
# Put together, this looks like a market that is comfortable with a somewhat steeper US curve and a somewhat softer dollar at the same time, rather than one big theme driving everything. That's a less exciting story than the sharp single-week moves earlier in this series, but it's arguably the more typical state of markets most weeks — which is itself worth noting for a series meant to record what's actually happening, not to manufacture drama.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-08-21 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** hold the 2s10s steepener, unchanged
# - **Direction & size (illustrative):** unchanged
# - **Entry context:** stable regime, fifth consecutive week without a flattening signal
# - **Time horizon:** unchanged
# - **Catalyst(s) to watch:** whether GBPUSD's series-high triggers any profit-taking commentary from desks that would be worth reading, even though this portfolio has no active GBP position to manage around it

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** unchanged — a flattening back toward +0.35pp
# - **Key risks to the trade:** complacency — five stable-to-good weeks is not a reason to stop checking the thesis each week
# - **Invalidation level / stop condition:** unchanged

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
