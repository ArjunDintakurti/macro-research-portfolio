# %% [markdown]
# # A steady curve, a softer dollar
#
# *Weekly note — week ending 21 August 2026*

# %% [markdown]
# Sterling touched its high for this entire series this week, at just under 1.17 against the dollar, with the euro close behind at its own high point too — both currencies extending the broad-dollar-softness theme flagged last week into a fifth consecutive week. The US curve, meanwhile, held roughly steady: 2s10s eased only marginally from last week's high, with the 2-year and 10-year yields both ticking up together by a similar amount rather than the curve itself changing shape.
#
# Put together, this reads as a market comfortable holding two views at once — a somewhat steeper US curve and a somewhat softer dollar — rather than one dominant theme driving everything, which is arguably closer to how markets behave most weeks than the sharper, single-story weeks earlier in this series. It's a less exciting note to write, but a more representative one, and there's value in recording what's typical alongside what's dramatic rather than only reaching for a story on the weeks that offer an obvious one.
#
# If anything is worth watching from here, it's whether sterling's new high for the series draws any profit-taking commentary from the desks that actually trade it in size — not because there's a position here to manage around it, but because a currency making a fresh high after a multi-week climb is often the point where the move either extends on genuine momentum or stalls on exhaustion, and it's not yet obvious which this is.

# %%
# chart

# %% [markdown]
# *Source: ECB reference rates, via the Frankfurter API*
