# %% [markdown]
# # A quiet week, and why that's worth saying plainly
#
# *Weekly note — week ending 10 July 2026*

# %% [markdown]
# Not every week has a new story in it, and this was one of those weeks — which is a legitimate thing for a note like this to say rather than manufacture a theme where there isn't one. The 2s10s spread ended the week exactly where it started, and the moves across the curve were small and roughly parallel: yields ticked up a little across the board rather than one part of the curve moving against another.
#
# A parallel shift like that usually means the market's overall sense of where rates are heading hasn't changed much — it's adjusting the general level slightly (perhaps a touch less confident in near-term cuts than a week ago) without revising its view on the shape of the cycle. That's a different, less interesting kind of move than a steepening or flattening, which is precisely why it doesn't need three paragraphs of analysis to explain.
#
# Sterling and the euro were similarly becalmed against the dollar, both within a hair of last week's levels. If there's a genuine gap in this week's picture, it's on the UK side: the most recent verified CPI print in the free data feed this note draws on is still from March 2025, which is a real data-access limitation rather than the UK economy having gone quiet — worth flagging honestly rather than pretending there's a fresher number behind this week's commentary.
#
# Next week is a reasonable point to start watching for whether this quiet holds into the heart of summer trading, when thinner volumes can occasionally exaggerate otherwise small moves.

# %%
# chart

# %% [markdown]
# *Source: US Treasury daily par yield curve*
