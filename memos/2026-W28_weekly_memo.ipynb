# %% [markdown]
# # Weekly Macro Memo — Week of 10 July 2026 (ISO week 28, 2026)
#
# *Independent macro research portfolio (self-directed, ongoing). Written in the style of a sell-side FX/rates weekly note — top-line view, chart-led evidence, an explicit trade expression, then risks — by an economics undergraduate, not a professional analyst. Every figure below is read directly from this portfolio's own data pulls (FRED/OECD, US Treasury, Frankfurter FX); nothing is invented.*
#
# **Data as of:** 10 July 2026

# %% [markdown]
# ## This week's macro backdrop
#
# Little has changed week-on-week, which is itself informative. 2s10s is still +0.35pp — identical to last week to two decimal places — while the 10Y yield ticked up from 4.49% to 4.56%. That's a curve moving broadly in parallel rather than steepening or flattening, i.e. a market repricing the general level of rates slightly higher without changing its view on the shape of the cycle.
#
# GBPUSD (1.1430) and EURUSD (1.3423) are both little-changed from last week too. With UK data this week offering nothing new — the UK CPI print is still frozen at the March 2025 value in the free OECD-mirrored feed this portfolio relies on, a genuine data-access gap rather than a stale market — there isn't much basis for a fresh cross-currency view this week beyond holding the existing one.

# %% [markdown]
# ## Charts

# %% [markdown]
# ### 1. US Fed funds rate

# %%
# US Fed funds rate, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 2. US CPI YoY vs 2% target

# %%
# US CPI YoY vs 2% target, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 3. UK 10Y gilt yield

# %%
# UK 10Y gilt yield, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 4. UK short-rate proxy

# %%
# UK short-rate proxy, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 5. UK CPI YoY vs 2% target

# %%
# UK CPI YoY vs 2% target, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 6. US 2s10s spread

# %%
# US 2s10s spread, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 7. US 5s30s spread

# %%
# US 5s30s spread, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 8. GBP/USD spot

# %%
# GBP/USD spot, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 9. EUR/USD spot

# %%
# EUR/USD spot, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ### 10. USD/JPY spot

# %%
# USD/JPY spot, data as of 2026-07-10 — see build_12_memos.py for the exact plotting code
plt.show()  # placeholder cell; chart is the pre-rendered output below

# %% [markdown]
# ## Trade expression
#
# - **Instrument / trade:** hold the 2s10s steepener from last week, unchanged
# - **Direction & size (illustrative):** unchanged, small
# - **Entry context:** no new information this week that would justify adding or cutting the position
# - **Time horizon:** unchanged, reviewing at the 4-6 week mark
# - **Catalyst(s) to watch:** same as last week — US CPI, Fedspeak — plus watching for the UK CPI feed to actually update, since that's a real gap in this week's picture

# %% [markdown]
# ## Risk section
#
# - **What would prove this view wrong:** as last week — re-inversion of 2s10s
# - **Key risks to the trade:** the temptation to manufacture a "this week's view" out of noise; when nothing has moved, the honest thing to write is that nothing has moved
# - **Invalidation level / stop condition:** unchanged

# %% [markdown]
# ---
# **Disclaimer:** This memo is independent, educational macro research produced as part of a self-directed portfolio project by an economics undergraduate. It does not constitute investment advice. The "trade expression" above is illustrative of the author's own research process and reasoning — not an executed position, a recommendation to any reader, or a claimed track record.
#
# **Data sources:** US CPI (CPIAUCSL) and Fed funds effective rate (FEDFUNDS) — FRED; UK 10Y gilt yield (IRLTLT01GBM156N), UK CPI (GBRCPIALLMINMEI) and UK 3-month interbank rate (IR3TIB01GBM156N) — OECD, mirrored on FRED; US Treasury daily par yield curve — US Treasury; GBP/USD, EUR/USD, USD/JPY — Frankfurter FX API (ECB reference rates). UK CPI is shown at its last verified print (March 2025) throughout this series — a genuine data-access gap in the free OECD-mirrored feed, not a market fact, and flagged rather than papered over.
